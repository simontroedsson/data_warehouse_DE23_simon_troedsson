# %%
import dlt
import json
import requests
import pandas as pd
from pathlib import Path
import os

url = "https://openparking.stockholm.se/LTF-Tolken/v1/servicedagar/street/Rind%C3%B6gatan?outputFormat=json&apiKey=d078a56a-bc6d-4072-abde-09c8fac53741"

def _get_ads(url_for_search):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))

# %%
json_response = _get_ads(url)
json_response["features"]
# Out:
# [{'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48459562',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.094421, 59.347663],
#     [18.095146, 59.347227],
#     [18.095183, 59.347206],
#     [18.096024, 59.346725],
#     [18.09675, 59.346313],
#     [18.096774, 59.346302],
#     [18.097154, 59.346134],
#     [18.09757, 59.345973],
#     [18.0981, 59.345793],
#     [18.098758, 59.345609],
#     [18.098796, 59.3456],
#     [18.099575, 59.345413],
#     [18.099872, 59.345362],
#     [18.100061, 59.345352],
#     [18.100173, 59.345368],
#     [18.1003, 59.345416],
#     [18.100394, 59.345471],
#     [18.10044, 59.345527],
#     [18.100473, 59.345596],
#     [18.100476, 59.345677],
#     [18.100464, 59.345749]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48459562,
#    'FEATURE_OBJECT_ID': 12416969,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-01734',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'P Avgift, boende',
#    'ADDRESS': 'Rindögatan 5 - 48',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=01734',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.094421, 59.345352, 18.100476, 59.347663]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48459918',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.093787, 59.347774],
#     [18.093767, 59.347774],
#     [18.093713, 59.347773],
#     [18.093688, 59.347772],
#     [18.093659, 59.34777],
#     [18.093629, 59.347766],
#     [18.093602, 59.347763],
#     [18.093572, 59.34776]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48459918,
#    'FEATURE_OBJECT_ID': 12371173,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-00847',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'Tidsreglerat parkerings-/stoppförbud',
#    'ADDRESS': 'Rindögatan 4 - Erik Dahlbergsgatan 56',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=00847',
#    'PARKING_RATE': 'avgiftsfri'},
#   'bbox': [18.093572, 59.34776, 18.093787, 59.347774]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48463147',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.093648, 59.347891], [18.093734, 59.347891]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48463147,
#    'FEATURE_OBJECT_ID': 16649939,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2019-05-31T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2019-01997',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 5,
#    'VF_PLATS_TYP': 'Reserverad p-plats motorcykel',
#    'ADDRESS': '<Adress saknas>',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2019&LopNr=01997',
#    'PARKING_RATE': 'taxa 13: Vardagar utom vardag före sön- och helgdag klockan 7.00 - 19.00, 5 kr/tim. Vardag före sön- och helgdag klockan 11.00 - 17.00, 3,75 kr/tim.'},
#   'bbox': [18.093648, 59.347891, 18.093734, 59.347891]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48464877',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.100295, 59.346088], [18.100286, 59.346142]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48464877,
#    'FEATURE_OBJECT_ID': 17558169,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2020-07-11T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'START_MONTH': 8,
#    'END_MONTH': 6,
#    'START_DAY': 16,
#    'END_DAY': 14,
#    'CITATION': '0180 2020-04627',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'Reserverad p-plats motorcykel',
#    'ADDRESS': 'Rindögatan 52',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2020&LopNr=04627',
#    'PARKING_RATE': 'taxa 13: Vardagar utom vardag före sön- och helgdag klockan 7.00 - 19.00, 5 kr/tim. Vardag före sön- och helgdag klockan 11.00 - 17.00, 3,75 kr/tim.'},
#   'bbox': [18.100286, 59.346088, 18.100295, 59.346142]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454020',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.096416, 59.346502], [18.096599, 59.346399]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454020,
#    'FEATURE_OBJECT_ID': 17746160,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2020-10-02T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2020-05433',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 15,
#    'VF_PLATS_TYP': 'Tidsreglerad lastplats',
#    'ADDRESS': 'Rindögatan 18 - 20',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2020&LopNr=05433',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.096416, 59.346399, 18.096599, 59.346502]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454021',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.100417, 59.345514],
#     [18.100354, 59.345473],
#     [18.100269, 59.345435],
#     [18.100218, 59.345411]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454021,
#    'FEATURE_OBJECT_ID': 17746161,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2020-10-02T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2020-05434',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 15,
#    'VF_PLATS_TYP': 'Tidsreglerad lastplats',
#    'ADDRESS': 'Rindögatan 27',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2020&LopNr=05434',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.100218, 59.345411, 18.100417, 59.345514]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454022',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.097749, 59.345909], [18.097959, 59.345838]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454022,
#    'FEATURE_OBJECT_ID': 17746165,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2020-10-02T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2020-05436',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 15,
#    'VF_PLATS_TYP': 'Tidsreglerad lastplats',
#    'ADDRESS': 'Rindögatan 28',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2020&LopNr=05436',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.097749, 59.345838, 18.097959, 59.345909]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454038',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.09447, 59.347626], [18.094608, 59.347543]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454038,
#    'FEATURE_OBJECT_ID': 17746162,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2020-10-02T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2020-05435',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 12,
#    'VF_PLATS_TYP': 'Lastplats',
#    'ADDRESS': 'Rindögatan 7',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2020&LopNr=05435',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.09447, 59.347543, 18.094608, 59.347626]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454274',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.100372, 59.346164], [18.100365, 59.346208]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454274,
#    'FEATURE_OBJECT_ID': 12371164,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-00843',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'Tidsreglerat parkerings-/stoppförbud',
#    'ADDRESS': 'Rindögatan 52',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=00843',
#    'PARKING_RATE': 'avgiftsfri'},
#   'bbox': [18.100365, 59.346164, 18.100372, 59.346208]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454129',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.097244, 59.346099],
#     [18.097191, 59.346121],
#     [18.097132, 59.346145],
#     [18.097075, 59.346167],
#     [18.097035, 59.346184]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454129,
#    'FEATURE_OBJECT_ID': 19454142,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2022-03-08T23:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2022-00492',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 15,
#    'VF_PLATS_TYP': 'Tidsreglerad lastplats',
#    'ADDRESS': 'Rindögatan 21A - 22',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2022&LopNr=00492',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.097035, 59.346099, 18.097244, 59.346184]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48454140',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.095376, 59.347096], [18.095493, 59.347029]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48454140,
#    'FEATURE_OBJECT_ID': 19155204,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2021-12-01T23:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2021-05117',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_METER': 10,
#    'VF_PLATS_TYP': 'Tidsreglerad lastplats',
#    'ADDRESS': 'Rindögatan 10 - 12',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2021&LopNr=05117',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.095376, 59.347029, 18.095493, 59.347096]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48456093',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.10058, 59.346223],
#     [18.100609, 59.346014],
#     [18.10062, 59.3459],
#     [18.10065, 59.345719],
#     [18.100661, 59.34561],
#     [18.100666, 59.345549],
#     [18.100661, 59.345508],
#     [18.100642, 59.345467],
#     [18.100593, 59.345406],
#     [18.100568, 59.345387]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48456093,
#    'FEATURE_OBJECT_ID': 12416830,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-01726',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'P Avgift, boende',
#    'ADDRESS': 'Rindögatan 52 - 44',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=01726',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.100568, 59.345387, 18.100666, 59.346223]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48456094',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.094186, 59.347649],
#     [18.094997, 59.347162],
#     [18.094999, 59.347161],
#     [18.095037, 59.347139],
#     [18.095037, 59.347139],
#     [18.095878, 59.346658],
#     [18.095878, 59.346658],
#     [18.096608, 59.346244],
#     [18.096612, 59.346242],
#     [18.096617, 59.346239],
#     [18.096646, 59.346227],
#     [18.096646, 59.346227],
#     [18.097028, 59.346057],
#     [18.097033, 59.346055],
#     [18.097454, 59.345892],
#     [18.097459, 59.34589],
#     [18.097995, 59.345709],
#     [18.098003, 59.345707],
#     [18.098666, 59.345521],
#     [18.098672, 59.345519],
#     [18.098712, 59.34551],
#     [18.098712, 59.34551],
#     [18.099496, 59.345322],
#     [18.099507, 59.345319],
#     [18.099818, 59.345266],
#     [18.09983, 59.345264],
#     [18.099841, 59.345263],
#     [18.100057, 59.345252],
#     [18.100067, 59.345251],
#     [18.100077, 59.345252],
#     [18.100087, 59.345252],
#     [18.100096, 59.345253],
#     [18.100169, 59.345263]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48456094,
#    'FEATURE_OBJECT_ID': 12416956,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-01733',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'P Avgift, boende',
#    'ADDRESS': 'Rindögatan 4 - 40',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=01733',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.094186, 59.345251, 18.100169, 59.347649]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48456095',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.093591, 59.34789], [18.093929, 59.347891]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48456095,
#    'FEATURE_OBJECT_ID': 12416989,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'CITATION': '0180 2017-01737',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATS_TYP': 'P Avgift, boende',
#    'ADDRESS': '<Adress saknas>',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=01737',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.093591, 59.34789, 18.093929, 59.347891]},
#  {'type': 'Feature',
#   'id': 'LTFR_SERVICEDAG.48457604',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[18.100305, 59.34528], [18.100363, 59.345302]]},
#   'geometry_name': 'GEOMETRY',
#   'properties': {'FID': 48457604,
#    'FEATURE_OBJECT_ID': 12416950,
#    'FEATURE_VERSION_ID': 1,
#    'EXTENT_NO': 1,
#    'VALID_FROM': '2017-05-17T22:00:00Z',
#    'START_TIME': 0,
#    'END_TIME': 600,
#    'START_WEEKDAY': 'torsdag',
#    'START_MONTH': 8,
#    'END_MONTH': 6,
#    'START_DAY': 16,
#    'END_DAY': 14,
#    'CITATION': '0180 2017-01730',
#    'STREET_NAME': 'Rindögatan',
#    'CITY_DISTRICT': 'Ladugårdsgärdet',
#    'PARKING_DISTRICT': 'Östermalm',
#    'VF_PLATSER': 10,
#    'VF_PLATS_TYP': 'P Avgift, boende',
#    'ADDRESS': 'Rindögatan 42',
#    'RDT_URL': 'https://rdt.transportstyrelsen.se/rdt/AF06_View.aspx?BeslutsMyndighetKod=0180&BeslutadAr=2017&LopNr=01730',
#    'PARKING_RATE': 'taxa 3: 20 kr/tim vardagar 7-19, 15 kr/tim dag före helgdag 11-17, Boende: 1100 kr/månad eller 75 kr/dygn'},
#   'bbox': [18.100305, 59.34528, 18.100363, 59.345302]}]
